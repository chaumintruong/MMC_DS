# %% [markdown]
# # Lab: Hiểu dữ liệu trong Pandas
# (Có một số phần buổi sau mới học nhưng thử tìm hiểu trước)

# %% [markdown]
# # 1. Đọc dữ liệu từ file

# %%
import pandas as pd

# %%
df_google_playstore = pd.read_csv('Google_Playstore.csv')
df_google_playstore.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# 2              50.0                58  True    0.0  ...
# 3              10.0                19  True    0.0  ...
# 4             100.0               478  True    0.0  ...
#
#                   Developer Website              Developer Email   Released  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com  26-Feb-20
# 1   https://webserveis.netlify.app/         webserveis@gmail.com  21-May-20
# 2                               NaN          vnacrewit@gmail.com   9-Aug-19
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com  10-Sep-18
# 4       http://www.horodyski.com.pl    rmilekhorodyski@gmail.com  21-Feb-20
#
#   Last Updated Content Rating  \
# 0    26-Feb-20       Everyone
# 1     6-May-21       Everyone
# 2    19-Aug-19       Everyone
# 3    13-Oct-18       Everyone
# 4    12-Nov-18       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice     Scraped Time
# 0            False          FALSE  6/15/2021 20:19
# 1            False          FALSE  6/15/2021 20:19
# 2            False          FALSE  6/15/2021 20:19
# 3            False          FALSE  6/15/2021 20:19
# 4            False          FALSE  6/15/2021 20:19
#
# [5 rows x 24 columns]

# %% [markdown]
# # 2. Hiểu dữ liệu

# %%
# Yêu cầu: Quan sát các thông tin về hàng và cột trong dữ liệu

# Thông tin về hàng
print(df_google_playstore.shape)

# Thông tin về cột
print(df_google_playstore.columns)

# Thông tin về cả hàng và cột
print(df_google_playstore.info())
# Out:
# (22670, 24)
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22670 entries, 0 to 22669
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App Name           22670 non-null  object
#  1   App Id             22670 non-null  object
#  2   Category           22670 non-null  object
#  3   Rating             22474 non-null  float64
#  4   Rating Count       22474 non-null  float64
#  5   Installs           22669 non-null  object
#  6   Minimum Installs   22669 non-null  float64
#  7   Maximum Installs   22670 non-null  int64
#  8   Free               22670 non-null  bool
#  9   Price              22670 non-null  float64
#  10  Currency           22669 non-null  object
#  11  Size               22670 non-null  object
#  12  Minimum Android    22602 non-null  object
#  13  Developer Id       22670 non-null  object
#  14  Developer Website  15230 non-null  object
#  15  Developer Email    22670 non-null  object
#  16  Released           22029 non-null  object
#  17  Last Updated       22670 non-null  object
#  18  Content Rating     22670 non-null  object
#  19  Privacy Policy     18607 non-null  object
#  20  Ad Supported       22670 non-null  bool
#  21  In App Purchases   22670 non-null  bool
#  22  Editors Choice     22670 non-null  object
#  23  Scraped Time       22669 non-null  object
# dtypes: bool(3), float64(4), int64(1), object(16)
# memory usage: 3.7+ MB
# None

# %%
# Yêu cầu: Quan sát 3 hàng đầu tiên trong dữ liệu bằng phương thức
df_google_playstore.head(3)
# Out:
#               App Name                      App Id      Category  Rating  \
# 0              Gakondo         com.ishakwe.gakondo     Adventure     0.0
# 1  Ampere Battery Info  com.webserveis.batteryinfo         Tools     4.4
# 2               Vibook        com.doantiepvien.crm  Productivity     0.0
#
#    Rating Count Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0           0.0      10+              10.0                15  True    0.0
# 1          64.0   5,000+            5000.0              7662  True    0.0
# 2           0.0      50+              50.0                58  True    0.0
#
#    ...                Developer Website         Developer Email   Released  \
# 0  ...      https://beniyizibyose.tk/#/  jean21101999@gmail.com  26-Feb-20
# 1  ...  https://webserveis.netlify.app/    webserveis@gmail.com  21-May-20
# 2  ...                              NaN     vnacrewit@gmail.com   9-Aug-19
#
#   Last Updated Content Rating  \
# 0    26-Feb-20       Everyone
# 1     6-May-21       Everyone
# 2    19-Aug-19       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
#
#   In App Purchases Editors Choice     Scraped Time
# 0            False          FALSE  6/15/2021 20:19
# 1            False          FALSE  6/15/2021 20:19
# 2            False          FALSE  6/15/2021 20:19
#
# [3 rows x 24 columns]

# %%
# Yêu cầu: Quan sát 7 hàng cuối trong dữ liệu bằng phương thức
df_google_playstore.tail(7)
# Out:
#                                  App Name  \
# 22663               American Arab Academy
# 22664                      Rogers & Kirby
# 22665                       Universal App
# 22666                 West Beach SLSC Inc
# 22667                       East Coast FM
# 22668           FNB Malayalam HealthPhone
# 22669  Theme for Asus ZenFone 4 Selfie HD
#
#                                                   App Id       Category  \
# 22663                                  com.American.Arab      Education
# 22664                        com.trustamerica.LibertyRak        Finance
# 22665                             com.safelogy.universal        Finance
# 22666                        com.sportsbag.westbeachslsc         Sports
# 22667                             com.eastcoastfm.player  Music & Audio
# 22668                       com.cdac.nutrition_malayalam      Education
# 22669  asus.zenfone4.selfie.max.zoom.zenfone2.zenfone...   Art & Design
#
#        Rating  Rating Count Installs  Minimum Installs  Maximum Installs  \
# 22663     0.0           0.0      10+              10.0                11
# 22664     0.0           0.0      10+              10.0                20
# 22665     0.0           0.0      10+              10.0                21
# 22666     0.0           0.0     100+             100.0               214
# 22667     0.0           0.0   1,000+            1000.0              2275
# 22668     0.0           0.0     100+             100.0               125
# 22669     4.8          32.0   1,000+            1000.0              3404
#
#        Free  Price  ...                        Developer Website  \
# 22663  True    0.0  ...                https://aaadentistry.org/
# 22664  True    0.0  ...  http://www.trustamerica.com/contact-us/
# 22665  True    0.0  ...                 https://www.safelogy.com
# 22666  True    0.0  ...               http://www.skoolbag.com.au
# 22667  True    0.0  ...                      http://eastcoast.fm
# 22668  True    0.0  ...                     https://www.cdac.in/
# 22669  True    0.0  ...                                      NaN
#
#                 Developer Email   Released Last Updated Content Rating  \
# 22663  aaadentistry20@gmail.com   8-May-20     8-May-20       Everyone
# 22664   dcurry@trustamerica.com   9-Dec-14    18-Sep-20       Everyone
# 22665      hotline@safelogy.com  28-Nov-17    11-Apr-19       Everyone
# 22666     admin@skoolbag.com.au   5-Aug-14    16-May-16       Everyone
# 22667          ecdml@ashmore.ie  20-Nov-18    23-Mar-21       Everyone
# 22668            ulearn@cdac.in  23-Aug-16     3-Mar-17       Everyone
# 22669     amazedtheme@gmail.com  18-Sep-17    20-Apr-19       Everyone
#
#                                           Privacy Policy Ad Supported  \
# 22663  https://www.privacypolicies.com/privacy/view/8...        False
# 22664  https://us.etrade.com/l/f/privacy-statement/pr...        False
# 22665                                                NaN        False
# 22666                 http://skoolbag.com.au/privacy.php        False
# 22667      https://aiir.com/mobile-apps/android/privacy/         True
# 22668                                                NaN        False
# 22669   http://privacy.gpforone.info/privacy.policy.html        False
#
#       In App Purchases Editors Choice     Scraped Time
# 22663            False          FALSE  6/15/2021 20:41
# 22664            False          FALSE  6/15/2021 20:41
# 22665            False          FALSE  6/15/2021 20:41
# 22666            False          FALSE  6/15/2021 20:41
# 22667            False          FALSE  6/15/2021 20:41
# 22668            False          FALSE  6/15/2021 20:41
# 22669            False             FA              NaN
#
# [7 rows x 24 columns]

# %%
# Yêu cầu: Quan sát tổng quan hình dạng của dữ liệu bằng phương thức
df_google_playstore.shape
# Out:
# (22670, 24)

# %% [markdown]
# Vậy câu lệnh trên trả về một tuple với 2 giá trị (a, b). Từ đó chúng ta có thể hiểu dữ liệu đang có a dòng và b cột

# %%
# Yêu cầu: Quan sát kiểu dữ liệu của từng cột trong dữ liệu
df_google_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22670 entries, 0 to 22669
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App Name           22670 non-null  object
#  1   App Id             22670 non-null  object
#  2   Category           22670 non-null  object
#  3   Rating             22474 non-null  float64
#  4   Rating Count       22474 non-null  float64
#  5   Installs           22669 non-null  object
#  6   Minimum Installs   22669 non-null  float64
#  7   Maximum Installs   22670 non-null  int64
#  8   Free               22670 non-null  bool
#  9   Price              22670 non-null  float64
#  10  Currency           22669 non-null  object
#  11  Size               22670 non-null  object
#  12  Minimum Android    22602 non-null  object
#  13  Developer Id       22670 non-null  object
#  14  Developer Website  15230 non-null  object
#  15  Developer Email    22670 non-null  object
#  16  Released           22029 non-null  object
#  17  Last Updated       22670 non-null  object
#  18  Content Rating     22670 non-null  object
#  19  Privacy Policy     18607 non-null  object
#  20  Ad Supported       22670 non-null  bool
#  21  In App Purchases   22670 non-null  bool
#  22  Editors Choice     22670 non-null  object
#  23  Scraped Time       22669 non-null  object
# dtypes: bool(3), float64(4), int64(1), object(16)
# memory usage: 3.7+ MB

# %%
# Yêu cầu: Quan sát thông tin của dữ liệu như số dữ liệu từng cột, kiểu dữ liệu, kích thước của bộ dữ liệu
df_google_playstore.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  22474.000000  2.247400e+04      2.266900e+04      2.267000e+04
# mean       2.210425  1.548588e+03      1.343784e+05      2.267921e+05
# std        2.107406  2.883528e+04      6.798136e+06      1.093632e+07
# min        0.000000  0.000000e+00      0.000000e+00      0.000000e+00
# 25%        0.000000  0.000000e+00      5.000000e+01      8.500000e+01
# 50%        3.000000  6.000000e+00      5.000000e+02      6.915000e+02
# 75%        4.300000  4.300000e+01      5.000000e+03      7.431250e+03
# max        5.000000  1.888256e+06      1.000000e+09      1.616141e+09
#
#               Price
# count  22670.000000
# mean       0.115916
# std        3.111982
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      399.990000

# %%
# Yêu cầu: Quan sát một số đặc điểm của trường dữ liệu dạng số
df_google_playstore.select_dtypes(include=['int64', 'float64'])
# Out:
#        Rating  Rating Count  Minimum Installs  Maximum Installs  Price
# 0         0.0           0.0              10.0                15    0.0
# 1         4.4          64.0            5000.0              7662    0.0
# 2         0.0           0.0              50.0                58    0.0
# 3         5.0           5.0              10.0                19    0.0
# 4         0.0           0.0             100.0               478    0.0
# ...       ...           ...               ...               ...    ...
# 22665     0.0           0.0              10.0                21    0.0
# 22666     0.0           0.0             100.0               214    0.0
# 22667     0.0           0.0            1000.0              2275    0.0
# 22668     0.0           0.0             100.0               125    0.0
# 22669     4.8          32.0            1000.0              3404    0.0
#
# [22670 rows x 5 columns]

# %%
# Yêu cầu: Từ các cột dữ liệu dạng số, hãy quan sát:
# - Giá trị lớn nhất,
# - Giá trị nhỏ nhất
# - Vị trí của giá trị lớn nhất
# - Vị trí của giá trị nhỏ nhất
# - Trung bình
# - Trung vị
# - Giá trị xuất hiện nhiều nhất
# - Tổng của toàn bộ dữ liệu
for col_name in df_google_playstore.select_dtypes(['float64', 'int64']).columns:
    print(col_name)
    print('Sum:', df_google_playstore[col_name].sum())
    print('Min:', df_google_playstore[col_name].min())
    print('Max:', df_google_playstore[col_name].max())
    print('Index value min:', df_google_playstore[col_name].idxmin())
    print('Index value max:', df_google_playstore[col_name].idxmax())
    print('Mean:', df_google_playstore[col_name].mean())
    print('Median:', df_google_playstore[col_name].median())
    print('Mode:', df_google_playstore[col_name].mode()[0])
    print()
# Out:
# Rating
# Sum: 49677.100000000006
# Min: 0.0
# Max: 5.0
# Index value min: 0
# Index value max: 3
# Mean: 2.2104253804396192
# Median: 3.0
# Mode: 0.0
#
# Rating Count
# Sum: 34802960.0
# Min: 0.0
# Max: 1888256.0
# Index value min: 0
# Index value max: 15871
# Mean: 1548.587701343775
# Median: 6.0
# Mode: 0.0
#
# Minimum Installs
# Sum: 3046223227.0
# Min: 0.0
# Max: 1000000000.0
# Index value min: 1213
# Index value max: 15871
# Mean: 134378.36812386962
# Median: 500.0
# Mode: 100.0
#
# Maximum Installs
# Sum: 5141376417
# Min: 0
# Max: 1616141394
# Index value min: 1213
# Index value max: 15871
# Mean: 226792.07838553155
# Median: 691.5
# Mode: 4
#
# Price
# Sum: 2627.8076359999995
# Min: 0.0
# Max: 399.99
# Index value min: 0
# Index value max: 20127
# Mean: 0.11591564340538155
# Median: 0.0
# Mode: 0.0
